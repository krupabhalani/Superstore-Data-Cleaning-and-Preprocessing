# %% [markdown]
# # Importing Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\My Drive\superstore_data.csv')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Sales
# ...

# %% [markdown]
# # Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   Sales        541909 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 37.2+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# Sales               0
# dtype: int64

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID          Sales
# count  541909.000000  541909.000000  406829.000000  541909.000000
# mean        9.552250       4.611114   15287.690570      17.987795
# std       218.081158      96.759853    1713.600303     378.810824
# min    -80995.000000  -11062.060000   12346.000000 -168469.600000
# 25%         1.000000       1.250000   13953.000000       3.400000
# 50%         3.000000       2.080000   15152.000000       9.750000
# 75%        10.000000       4.130000   16791.000000      17.400000
# max     80995.000000   38970.000000   18287.000000  168469.600000

# %% [markdown]
# # Handling Missing Values

# %%
df.dropna(subset=['CustomerID'], inplace=True) # Remove rows where CustomerID has NaN values

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Sales
# ...

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# Sales          0
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
df['InvoiceNo'].value_counts()
# Out:
# 576339    542
# 579196    533
# 580727    529
# 578270    442
# 573576    435
#          ...
# 554155      1
# 570248      1
# 545414      1
# 545418      1
# 565192      1
# Name: InvoiceNo, Length: 22190, dtype: int64

# %%
df['StockCode'].value_counts()
# Out:
# 85123A    2077
# 22423     1905
# 85099B    1662
# 84879     1418
# 47566     1416
#           ...
# 84620        1
# 90038B       1
# 84551        1
# 84614A       1
# 20957        1
# Name: StockCode, Length: 3684, dtype: int64

# %%
df['Quantity'].value_counts()
# Out:
#  1        73314
#  12       60033
#  2        58003
#  6        37688
#  4        32183
#           ...
#  828          1
#  560          1
# -408          1
#  512          1
# -80995        1
# Name: Quantity, Length: 436, dtype: int64

# %%
df['Quantity'].unique()
# Out:
# array([     6,      8,      2,     32,      3,      4,     24,     12,
#            48,     18,     20,     36,     80,     64,     10,    120,
#            96,     23,      5,      1,     -1,     50,     40,    100,
#           192,    432,    144,    288,    -12,    -24,     16,      9,
#           128,     25,     30,     28,      7,     72,    200,    600,
#           480,     -6,     14,     -2,     -4,     -5,     -7,     -3,
#            11,     70,    252,     60,    216,    384,     27,    108,
#            52,  -9360,     75,    270,     42,    240,     90,    320,
#            17,   1824,    204,     69,    -36,   -192,   -144,    160,
#          2880,   1400,     19,     39,    -48,    -50,     56,     13,
#          1440,     -8,     15,    720,    -20,    156,    324,     41,
#           -10,    -72,    -11,    402,    378,    150,    300,     22,
#            34,    408,    972,    208,   1008,     26,   1000,    -25,
# ...

# %%
df['Quantity'] = df['Quantity'].abs()

# %%
df['InvoiceDate'].value_counts()
# Out:
# 11/14/2011 15:27    543
# 11/28/2011 15:54    534
# 12/5/2011 17:17     530
# 11/23/2011 13:39    444
# 10/31/2011 14:09    436
#                    ...
# 11/15/2011 10:54      1
# 4/8/2011 13:20        1
# 9/15/2011 17:02       1
# 9/15/2011 16:57       1
# 3/21/2011 11:02       1
# Name: InvoiceDate, Length: 20460, dtype: int64

# %%
df['UnitPrice'].value_counts()
# Out:
# 1.25      46555
# 1.65      37503
# 2.95      27211
# 0.85      26396
# 0.42      22032
#           ...
# 3.56          1
# 4.37          1
# 6.89          1
# 0.98          1
# 224.69        1
# Name: UnitPrice, Length: 620, dtype: int64

# %%
df['UnitPrice'].unique()
# Out:
# array([2.55000e+00, 3.39000e+00, 2.75000e+00, 7.65000e+00, 4.25000e+00,
#        1.85000e+00, 1.69000e+00, 2.10000e+00, 3.75000e+00, 1.65000e+00,
#        4.95000e+00, 9.95000e+00, 5.95000e+00, 7.95000e+00, 8.50000e-01,
#        6.50000e-01, 1.25000e+00, 2.95000e+00, 1.95000e+00, 4.20000e-01,
#        1.80000e+01, 1.06000e+00, 6.95000e+00, 1.09500e+01, 3.45000e+00,
#        5.50000e-01, 3.80000e-01, 1.45000e+00, 3.95000e+00, 6.75000e+00,
#        2.75000e+01, 1.49500e+01, 1.69500e+01, 4.65000e+00, 6.45000e+00,
#        1.27500e+01, 1.99500e+01, 8.50000e+00, 3.82000e+00, 3.37000e+00,
#        5.45000e+00, 6.35000e+00, 7.20000e-01, 6.40000e-01, 1.00000e-01,
#        3.20000e-01, 1.48000e+00, 2.90000e-01, 1.65000e+02, 3.57500e+01,
#        3.35000e+00, 1.06500e+01, 1.50000e+01, 9.50000e-01, 2.10000e-01,
#        1.20000e-01, 2.40000e-01, 3.25000e+00, 1.49000e+00, 2.25000e+00,
#        1.55000e+00, 1.89500e+01, 8.95000e+00, 5.00000e+01, 2.99500e+01,
# ...

# %%
df['UnitPrice'] = df['UnitPrice'].abs()

# %%
df['CustomerID'].value_counts()
# Out:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          361878
# Germany                   9495
# France                    8491
# EIRE                      7485
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1480
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# ...

# %%
df['Sales'].value_counts()
# Out:
#  15.00      20082
#  19.80      11033
#  17.70       9174
#  16.50       8490
#  10.20       8028
#             ...
# -835.20         1
#  812.00         1
#  2610.00        1
#  4401.00        1
#  66.36          1
# Name: Sales, Length: 3878, dtype: int64

# %%
df['Sales'] = df['Sales'].abs()

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID          Sales
# count  406829.000000  406829.000000  406829.000000  406829.000000
# mean       13.412279       3.460471   15287.690570      23.407255
# std       248.624170      69.315162    1713.600303     427.437730
# min         1.000000       0.000000   12346.000000       0.000000
# 25%         2.000000       1.250000   13953.000000       4.680000
# 50%         5.000000       1.950000   15152.000000      11.800000
# 75%        12.000000       3.750000   16791.000000      19.800000
# max     80995.000000   38970.000000   18287.000000  168469.600000

# %%
df = df[df['UnitPrice'] != 0] # Remove rows where the UnitPrice is 0
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Sales
# ...

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID          Sales
# count  406789.000000  406789.000000  406789.000000  406789.000000
# mean       13.379467       3.460811   15287.795830      23.409556
# std       247.858601      69.318561    1713.573064     427.458681
# min         1.000000       0.001000   12346.000000       0.001000
# 25%         2.000000       1.250000   13954.000000       4.680000
# 50%         5.000000       1.950000   15152.000000      11.800000
# 75%        12.000000       3.750000   16791.000000      19.800000
# max     80995.000000   38970.000000   18287.000000  168469.600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406789 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406789 non-null  object
#  1   StockCode    406789 non-null  object
#  2   Description  406789 non-null  object
#  3   Quantity     406789 non-null  int64
#  4   InvoiceDate  406789 non-null  object
#  5   UnitPrice    406789 non-null  float64
#  6   CustomerID   406789 non-null  float64
#  7   Country      406789 non-null  object
#  8   Sales        406789 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 31.0+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']) # InvoiceDate is in object thus, we converted into datetime
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8320\4127488558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']) # InvoiceDate is in object thus, we converted into datetime

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Sales
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406789 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406789 non-null  object
#  1   StockCode    406789 non-null  object
#  2   Description  406789 non-null  object
#  3   Quantity     406789 non-null  int64
#  4   InvoiceDate  406789 non-null  datetime64[ns]
#  5   UnitPrice    406789 non-null  float64
#  6   CustomerID   406789 non-null  float64
#  7   Country      406789 non-null  object
#  8   Sales        406789 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 31.0+ MB

# %% [markdown]
# # Exporting csv File

# %%
df.to_csv('Cleaned_superstore_data.csv')
